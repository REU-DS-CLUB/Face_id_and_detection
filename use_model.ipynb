# %%
import torch
import src.models as mdls
import src.utils as utils
import torchvision.transforms as tf

# %%
model = mdls.InspectorGadjet()

# %%
path_model_dict = '/Users/andreisuhov/Desktop/checkpoint_epoch_13_inspector_gadjet.pth'
model_state_dict = torch.load(path_model_dict, map_location=torch.device('cpu'))['model_state_dict']
model.load_state_dict(model_state_dict)
model.eval()
None

# %%
utils.cam_capture(0, model=model)
# Out:
# [31.2510986328125, 27.782480239868164, 43.679298400878906, 40.989471435546875]
# [312, 156, 436, 230]
# [53.10592269897461, 30.823293685913086, 78.13673400878906, 75.33053588867188]
# [531, 173, 781, 423]
# [53.19536209106445, 30.963830947875977, 77.70928955078125, 74.66888427734375]
# [531, 174, 777, 420]
# [53.35184097290039, 31.36280632019043, 77.81100463867188, 75.0503158569336]
# [533, 176, 778, 422]
# [53.019527435302734, 31.392812728881836, 77.42318725585938, 75.02239990234375]
# [530, 176, 774, 422]
# [53.36983108520508, 31.5557918548584, 77.87625122070312, 75.55013275146484]
# [533, 177, 778, 424]
# [53.03276443481445, 31.712495803833008, 77.43807983398438, 75.87226867675781]
# [530, 178, 774, 426]
# [52.986202239990234, 31.898319244384766, 77.22307586669922, 75.18031311035156]
# [529, 179, 772, 422]
# [52.90194320678711, 31.696332931518555, 77.58319091796875, 74.872802734375]
# [529, 178, 775, 421]
# ...

# %%
utils.recognition_cam(0, model=model)
