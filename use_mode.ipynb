# %%
import torch
import src.models as mdls
import src.utils as utils

import torchvision.transforms as tf

# %%
model = mdls.InspectorGadjet()

# %%
model_state_dict = torch.load('/Users/andreisuhov/Desktop/checkpoint_epoch_15.pth', map_location=torch.device('cpu'))['model_state_dict']
model.load_state_dict(model_state_dict)
# Out:
# <All keys matched successfully>

# %%
model.eval()

# %%
utils.cam_capture(0, model=model)
# Out:
# given tensor -  (tensor([[-1.0837,  1.1070]]), tensor([[25.3892, 18.2753, 48.8035, 45.5416]]))
# extracted xes -  tensor(25.3892) tensor(18.2753) tensor(48.8035) tensor(45.5416)
# int xes coord -  25 18 48 45
# final coord -  250 101 480 253
# [250, 101, 480, 253]
# given tensor -  (tensor([[-1.0763,  1.0968]]), tensor([[29.3364, 19.4351, 51.8328, 46.0789]]))
# extracted xes -  tensor(29.3364) tensor(19.4351) tensor(51.8328) tensor(46.0789)
# int xes coord -  29 19 51 46
# final coord -  290 106 510 258
# [290, 106, 510, 258]
# given tensor -  (tensor([[-1.0939,  1.1091]]), tensor([[32.5552, 20.4990, 54.1869, 46.4943]]))
# extracted xes -  tensor(32.5552) tensor(20.4990) tensor(54.1869) tensor(46.4943)
# int xes coord -  32 20 54 46
# final coord -  320 112 540 258
# [320, 112, 540, 258]
# given tensor -  (tensor([[-1.1048,  1.1190]]), tensor([[34.3781, 20.6639, 55.4784, 46.2781]]))
# extracted xes -  tensor(34.3781) tensor(20.6639) tensor(55.4784) tensor(46.2781)
# ...
