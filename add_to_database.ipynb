# %%
import torch
import src.utils as utils

from src import models
import numpy as np

import src.utils as utils
import torchvision.transforms as tf

# %%
config = utils.get_options()
det_model, rec_model = utils.get_models_with_weights()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17520/3391743698.py in <module>
#       1 config = utils.get_options()
# ----> 2 det_model, rec_model = utils.get_models_with_weights()
#
# c:\Users\pasin\DS\Клуб\detection\Face_id_and_detection\src\utils.py in get_models_with_weights()
#     686
#     687
# --> 688 def get_models_with_weights():
#     689     det_model = models.InspectorGadjet()
#     690     model_state_dict = torch.load(config['path_to_detection_weights'], map_location=torch.device('cpu'))['model_state_dict']
#
# c:\Users\pasin\anaconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     789         pickle_load_args['encoding'] = 'utf-8'
#     790
# --> 791     with _open_file_like(f, 'rb') as opened_file:
#     792         if _is_zipfile(opened_file):
#     793             # The zipfile reader is going to advance the current file position.
#
# c:\Users\pasin\anaconda3\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# c:\Users\pasin\anaconda3\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     250 class _open_file(_opener):
#     251     def __init__(self, name, mode):
# --> 252         super().__init__(open(name, mode))
#     253
#     254     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/pasin/DS/Клуб/detection/Face_id_and_detection/db_test/detection.pth'

# %%
print("Enter number of action: \n\t1. Add new person\n\t2. Delete person by name ")

action = int(input())

if action == 1:
    image_folder_path = input("Enter path to folder with photos in .png format ")
    name = input("Enter name of photo owner ")
    images =  utils.add2db(image_folder_path, name, model=det_model, rec_model=rec_model)
elif action == 2:
    name = input("Enter name of photo owner ")
    utils.drop_from_database(name)
# Out:
# Enter number of action:
# 	1. Add new person
# 	2. Delete person by name

# %%
images[2]
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
utils.recognition_cam(0, model=det_model, embedding_model=rec_model.encoder, database_path='Database.csv')
